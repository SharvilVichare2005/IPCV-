# %% [markdown]
# * Name - Sharvil Vichare
# * Roll NO - B39
# * PRN - 2324000814

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
data = pd.read_csv('train 4.csv')

# %%
train_data = data.head(37800)
val_data = data.tail(4200)

train_labels = train_data.pop('label')
val_labels = val_data.pop('label')

# %%
tf_train_data = tf.data.Dataset.from_tensor_slices((train_data.values, train_labels.values))
tf_val_data = tf.data.Dataset.from_tensor_slices((val_data.values, val_labels.values))

print(tf_train_data)
print(tf_val_data)
# Out:
# <_TensorSliceDataset element_spec=(TensorSpec(shape=(784,), dtype=tf.int64, name=None), TensorSpec(shape=(), dtype=tf.int64, name=None))>
# <_TensorSliceDataset element_spec=(TensorSpec(shape=(784,), dtype=tf.int64, name=None), TensorSpec(shape=(), dtype=tf.int64, name=None))>

# %%
plt.figure(figsize=(10,10))
i = 0

for image, label in tf_train_data.take(5):
    plt.subplot(1,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)

    plt.imshow(image.numpy().reshape((28, 28)), cmap='gray')
    plt.xlabel(label.numpy())

    i = i + 1

# %%
def preprocess_image(image, label):
    image = tf.reshape(image, [28, 28, 1])
    image = tf.cast(image, tf.float32) / 255.

    return image, label

tf_train_data = tf_train_data.map(
    preprocess_image,
    num_parallel_calls=tf.data.experimental.AUTOTUNE
)

tf_val_data = tf_val_data.map(
    preprocess_image,
    num_parallel_calls=tf.data.experimental.AUTOTUNE
)

print(tf_train_data)
print(tf_val_data)
# Out:
# <_ParallelMapDataset element_spec=(TensorSpec(shape=(28, 28, 1), dtype=tf.float32, name=None), TensorSpec(shape=(), dtype=tf.int64, name=None))>
# <_ParallelMapDataset element_spec=(TensorSpec(shape=(28, 28, 1), dtype=tf.float32, name=None), TensorSpec(shape=(), dtype=tf.int64, name=None))>

# %%
def pipeline(tf_data):
    tf_data = tf_data.shuffle(100)
    tf_data = tf_data.batch(32)
    tf_data = tf_data.prefetch(tf.data.experimental.AUTOTUNE)

    return tf_data

tf_train_data = pipeline(tf_train_data)
tf_val_data = pipeline(tf_val_data)

print(tf_train_data)
print(tf_val_data)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 28, 28, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 28, 28, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(6, (5, 5), activation='relu', padding='same', input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Conv2D(16, (5, 5), activation='relu', padding='valid'),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(120, activation='relu'),
    tf.keras.layers.Dense(84, activation='relu'),

    tf.keras.layers.Dense(10, activation='softmax'),
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
optimiser = tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(
    optimizer=optimiser,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 6)      │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 6)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 10, 10, 16)     │         2,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 5, 5, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 400)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 120)            │        48,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 84)             │        10,164 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │           850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 61,706 (241.04 KB)
#  Trainable params: 61,706 (241.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(monitor='loss', patience=2, verbose=1),
    tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5, verbose=1),
]

# %%
train_log = model.fit(
    tf_train_data,
    validation_data=tf_val_data,
    epochs=30,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9257 - loss: 0.2395 - val_accuracy: 0.9676 - val_loss: 0.0942 - learning_rate: 0.0010
# Epoch 2/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9753 - loss: 0.0796 - val_accuracy: 0.9781 - val_loss: 0.0703 - learning_rate: 0.0010
# Epoch 3/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9832 - loss: 0.0551 - val_accuracy: 0.9755 - val_loss: 0.0732 - learning_rate: 0.0010
# Epoch 4/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9875 - loss: 0.0417 - val_accuracy: 0.9840 - val_loss: 0.0530 - learning_rate: 0.0010
# Epoch 5/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9893 - loss: 0.0332 - val_accuracy: 0.9833 - val_loss: 0.0533 - learning_rate: 0.0010
# Epoch 6/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9922 - loss: 0.0267 - val_accuracy: 0.9840 - val_loss: 0.0518 - learning_rate: 0.0010
# Epoch 7/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9922 - loss: 0.0228 - val_accuracy: 0.9800 - val_loss: 0.0661 - learning_rate: 0.0010
# Epoch 8/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9940 - loss: 0.0190 - val_accuracy: 0.9814 - val_loss: 0.0671 - learning_rate: 0.0010
# Epoch 9/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9945 - loss: 0.0167 - val_accuracy: 0.9850 - val_loss: 0.0483 - learning_rate: 0.0010
# Epoch 10/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9954 - loss: 0.0137 - val_accuracy: 0.9850 - val_loss: 0.0566 - learning_rate: 0.0010
# Epoch 11/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9958 - loss: 0.0122 - val_accuracy: 0.9857 - val_loss: 0.0675 - learning_rate: 0.0010
# Epoch 12/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9957 - loss: 0.0127 - val_accuracy: 0.9852 - val_loss: 0.0654 - learning_rate: 0.0010
# Epoch 13/30
# 1171/1182 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9952 - loss: 0.0130
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9951 - loss: 0.0133 - val_accuracy: 0.9890 - val_loss: 0.0414 - learning_rate: 0.0010
# Epoch 14/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9987 - loss: 0.0042 - val_accuracy: 0.9914 - val_loss: 0.0354 - learning_rate: 1.0000e-04
# Epoch 15/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9996 - loss: 0.0017 - val_accuracy: 0.9919 - val_loss: 0.0358 - learning_rate: 1.0000e-04
# Epoch 16/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9998 - loss: 9.3679e-04 - val_accuracy: 0.9917 - val_loss: 0.0365 - learning_rate: 1.0000e-04
# Epoch 17/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9999 - loss: 5.5218e-04 - val_accuracy: 0.9921 - val_loss: 0.0376 - learning_rate: 1.0000e-04
# Epoch 18/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 3.2600e-04 - val_accuracy: 0.9919 - val_loss: 0.0394 - learning_rate: 1.0000e-04
# Epoch 19/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 1.0000 - loss: 1.9081e-04 - val_accuracy: 0.9919 - val_loss: 0.0417 - learning_rate: 1.0000e-04
# Epoch 20/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 1.2164e-04 - val_accuracy: 0.9919 - val_loss: 0.0440 - learning_rate: 1.0000e-04
# Epoch 21/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 8.3329e-05 - val_accuracy: 0.9917 - val_loss: 0.0463 - learning_rate: 1.0000e-04
# Epoch 22/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 1.0000 - loss: 6.6806e-05 - val_accuracy: 0.9914 - val_loss: 0.0486 - learning_rate: 1.0000e-04
# Epoch 23/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.8323e-05
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 2.7293e-05 - val_accuracy: 0.9917 - val_loss: 0.0509 - learning_rate: 1.0000e-04
# Epoch 24/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 1.0000 - loss: 1.5964e-05 - val_accuracy: 0.9919 - val_loss: 0.0514 - learning_rate: 1.0000e-05
# Epoch 25/30
# 1176/1182 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.4678e-05
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 1.3462e-05 - val_accuracy: 0.9917 - val_loss: 0.0519 - learning_rate: 1.0000e-05
# Epoch 26/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 1.1991e-05 - val_accuracy: 0.9919 - val_loss: 0.0519 - learning_rate: 1.0000e-06
# Epoch 27/30
# 1171/1182 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.2721e-05
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 1.0000 - loss: 1.1802e-05 - val_accuracy: 0.9917 - val_loss: 0.0520 - learning_rate: 1.0000e-06
# Epoch 28/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 1.1566e-05 - val_accuracy: 0.9917 - val_loss: 0.0521 - learning_rate: 1.0000e-07
# Epoch 29/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.2424e-05
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 1.1541e-05 - val_accuracy: 0.9917 - val_loss: 0.0521 - learning_rate: 1.0000e-07
# Epoch 30/30
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 1.1513e-05 - val_accuracy: 0.9917 - val_loss: 0.0521 - learning_rate: 1.0000e-08

# %%
plt.plot(train_log.history['accuracy'], label='accuracy')
plt.plot(train_log.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

print('Training accuracy: %f' % train_log.history['accuracy'][-1])
print('Validation accuracy: %f' % train_log.history['val_accuracy'][-1])
# Out:
# Training accuracy: 1.000000
# Validation accuracy: 0.991667

# %%
test_data = pd.read_csv('test 2.csv')
tf_test_data = tf.data.Dataset.from_tensor_slices(([test_data.to_numpy().reshape(len(test_data), 28, 28, 1)]))

# %%
predictions = model.predict(tf_test_data)
predictions = np.argmax(predictions, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step

# %%
plt.figure(figsize=(10,10))

for i, row in test_data.head(15).iterrows():
    plt.subplot(3,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)

    plt.imshow(row.values.reshape((28, 28)), cmap='gray')
    plt.xlabel(predictions[i])

# %%
predictions_df = pd.DataFrame(data={'Label': predictions}, index=pd.RangeIndex(start=1, stop=28001))
predictions_df.index = predictions_df.index.rename('ImageId')

predictions_df.to_csv('submission_file.csv')
